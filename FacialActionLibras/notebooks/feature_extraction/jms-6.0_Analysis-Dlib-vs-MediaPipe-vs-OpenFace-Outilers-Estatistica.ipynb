# %% [markdown]
# # Releases
#
# - Adicionando o extrator OpenFace na Análise
#
# ## Configuração
#
# Env conda: 2way

# %% [markdown]
# # Análise Comparativa de Extratores de Features Faciais
#
# Neste jupyter notebook, podemos realizar a leitura dos arquivos que contém as features extraídas da face (landmarks) e compará-los a nível de quantidade de frames com landmarks detectados entre o tipo do extrator vs variação de data augmentation.
#
#
# Os augmentation foram realizados a partir do script 'FacialActionLibras/src/data/augmentation.py'
#
# ## Extratores:
#
# - Dlib
# - Mediapipe
# - OpenFace
#
# ## Augmentations:
#
# - rot90
#     - Parâmetros: k=1
# - adjust_contrast
#     - Parâmetros: contrast_factor=0.25
# - adjust_hue
#     - Parâmetros: delta=1.5
# - stateless_random_brightness
#     - Parâmetros: max_delta=0.95, seed=(0,0)
# - adjust_jpeg_quality
#     - Parâmetros: jpeg_quality==10
# - adjust_brightness
#     - Parâmetros: delta=0.5
# - rgb_to_grayscale
#
# ## Referência:
# https://www.tensorflow.org/api_docs/python/tf/image/

# %%
# !pip install mediapy
# Out:
# Requirement already satisfied: mediapy in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (1.0.3)
# Requirement already satisfied: ipython in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from mediapy) (7.22.0)
# Requirement already satisfied: numpy in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from mediapy) (1.20.3)
# Requirement already satisfied: matplotlib in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from mediapy) (3.4.2)
# Requirement already satisfied: Pillow in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from mediapy) (8.3.1)
# Requirement already satisfied: pygments in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (2.9.0)
# Requirement already satisfied: pexpect>4.3 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (4.8.0)
# Requirement already satisfied: pickleshare in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (0.7.5)
# Requirement already satisfied: decorator in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (5.0.9)
# Requirement already satisfied: traitlets>=4.2 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (5.0.5)
# Requirement already satisfied: setuptools>=18.5 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (52.0.0.post20210125)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (3.0.17)
# Requirement already satisfied: jedi>=0.16 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (0.17.2)
# Requirement already satisfied: backcall in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from ipython->mediapy) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from jedi>=0.16->ipython->mediapy) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from pexpect>4.3->ipython->mediapy) (0.7.0)
# Requirement already satisfied: wcwidth in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->mediapy) (0.2.5)
# Requirement already satisfied: ipython-genutils in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from traitlets>=4.2->ipython->mediapy) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from matplotlib->mediapy) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from matplotlib->mediapy) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from matplotlib->mediapy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from matplotlib->mediapy) (0.10.0)
# Requirement already satisfied: six in /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->mediapy) (1.16.0)

# %%
import os
import glob
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import mediapy as media
import cv2
import utils as u
from scipy import stats

# %% [markdown]
# ## Load Data

# %%
def get_name_video(string):
    new_name = string.split('/')[-1]
    return new_name

def get_files(path, extrator, aug, extension):
    """
    Descrição: Recebe um path e lista todos os arquivos e seta o extrator + tipo de augmentation
    Retorna um dataframe com todos os files concatenados de um determinado path
    """
    all_filenames = []
    df = pd.DataFrame()
    df_interno = pd.DataFrame()

    if(aug == 'original'):
        all_filenames = [i for i in glob.glob(path+'*.{}'.format(extension))]
    else:
        all_filenames = [i for i in glob.glob(path+aug+'/'+'*.{}'.format(extension))]
        
    if(len(all_filenames) > 0):
        
        for f in all_filenames:    
            df_interno = pd.read_csv(f, sep=";", index_col=None)
            if(' video_name' in df_interno.columns):
                df_interno.rename(columns={' video_name':'video_name'}, inplace=True)

            df = pd.concat([df, df_interno], axis=0)

        #df = pd.concat([pd.read_csv(f, sep=";", index_col=None) for f in all_filenames ])
        df['extractor'] = extrator
        df['aug'] = aug
        #print(df['video_name'])

        df['video_name'] = df.apply(lambda row : get_name_video(row['video_name']), axis = 1)
        df['video_name'] = df['video_name'].str.split('.', expand=True)[0]
        df['class'] = df['video_name'].str.split('_', expand=True)[1]
        
        
        
        return df[['frame', 'video_name', 'keys', 'extractor', 'aug', 'class']]
        
    



def join_files(paths, aug, extension='csv'):
    
    """
    Descrição: Recebe um dict dos paths de cada base submetida por cada extrator
    Retorna o dataframe combinado
    """
    
    df_combined = pd.DataFrame()
    
    if(aug=='original'):

        for key, value in paths.items():
            print(key, value)
            df = get_files(value, key, aug, extension)
            df_combined = pd.concat([df_combined, df], axis=0)
    
    elif(aug=='aug'):
        
        for key, value in paths.items():
            print(key, value)
            for aug in os.listdir(paths[key]):
                print(aug)
                df = get_files(value, key, aug, extension='csv')
                df_combined = pd.concat([df_combined, df], axis=0)
        
        
    return df_combined

# %%
#Original
inputs_orig = {
    'dlib': '../../data/processed/dlib/UCF-101-Analysis/',
    'mediapipe': '../../data/processed/mediapipe/UCF-101-Analysis/',
    'openface': '../../data/processed/openface/UCF-101-Analysis/'
}

df_combined_orig = join_files(inputs_orig, aug='original', extension='csv')
df_combined_orig.shape
# Out:
# dlib ../../data/processed/dlib/UCF-101-Analysis/
# mediapipe ../../data/processed/mediapipe/UCF-101-Analysis/
# openface ../../data/processed/openface/UCF-101-Analysis/
# (403452, 6)

# %%
df_combined_orig
# Out:
#      frame                video_name  \
# 0        1   v_BrushingTeeth_g21_c04
# 1        2   v_BrushingTeeth_g21_c04
# 2        3   v_BrushingTeeth_g21_c04
# 3        4   v_BrushingTeeth_g21_c04
# 4        5   v_BrushingTeeth_g21_c04
# ..     ...                       ...
# 176    177  v_ApplyEyeMakeup_g20_c06
# 177    178  v_ApplyEyeMakeup_g20_c06
# 178    179  v_ApplyEyeMakeup_g20_c06
# 179    180  v_ApplyEyeMakeup_g20_c06
# 180    181  v_ApplyEyeMakeup_g20_c06
#
#                                                   keys extractor       aug  \
# 0    [[70, 27], [68, 48], [69, 70], [75, 92], [83, ...      dlib  original
# 1    [[82, 31], [80, 49], [80, 69], [84, 87], [88, ...      dlib  original
# 2    [[77, 28], [75, 47], [76, 68], [80, 88], [86, ...      dlib  original
# 3    [[79, 30], [77, 48], [77, 68], [81, 88], [86, ...      dlib  original
# 4    [[77, 28], [75, 45], [75, 65], [79, 85], [83, ...      dlib  original
# ..                                                 ...       ...       ...
# 176  [[83.8, 94.2],[84.0, 111.6],[86.0, 128.8],[89....  openface  original
# 177  [[83.9, 95.6],[84.4, 113.2],[86.6, 130.7],[90....  openface  original
# 178  [[84.4, 91.9],[84.3, 109.3],[86.1, 126.8],[89....  openface  original
# 179  [[84.7, 89.3],[84.3, 106.7],[85.7, 124.4],[88....  openface  original
# 180  [[85.5, 88.7],[84.8, 105.9],[86.0, 123.4],[88....  openface  original
#
#               class
# 0     BrushingTeeth
# 1     BrushingTeeth
# 2     BrushingTeeth
# 3     BrushingTeeth
# 4     BrushingTeeth
# ..              ...
# 176  ApplyEyeMakeup
# 177  ApplyEyeMakeup
# 178  ApplyEyeMakeup
# 179  ApplyEyeMakeup
# 180  ApplyEyeMakeup
#
# [403452 rows x 6 columns]

# %%
daa = df_combined_orig.loc[df_combined_orig.aug == 'original']
daa.groupby('class').agg('count')
# Out:
#                  frame  video_name   keys  extractor     aug
# class
# ApplyEyeMakeup   73074       73074  59080      73074   73074
# BrushingTeeth    99015       99015  70328      99015   99015
# PlayingFlute    124383      124383  54271     124383  124383
# ShavingBeard    106980      106980  64151     106980  106980

# %%
daa = df_combined_orig.loc[df_combined_orig.aug == 'original']
daa.groupby('extractor').agg('count')
# Out:
#             frame  video_name    keys     aug   class
# extractor
# dlib       134484      134484   45776  134484  134484
# mediapipe  134484      134484  110407  134484  134484
# openface   134484      134484   91647  134484  134484

# %%
73074+99015+124383+106980
# Out:
# 403452

# %%
#Augmentation
inputs_aug = {
    'dlib': '../../data/processed/dlib/UCF-101-Analysis-augmentation/',
    'mediapipe': '../../data/processed/mediapipe/UCF-101-Analysis-augmentation/',
    'openface': '../../data/processed/openface/UCF-101-Analysis-augmentation/'
}

df_combined_aug = join_files(inputs_aug, aug='aug', extension='csv')
df_combined_aug.shape
# Out:
# dlib ../../data/processed/dlib/UCF-101-Analysis-augmentation/
# rot90
# adjust_contrast
# adjust_hue
# stateless_random_brightness
# adjust_jpeg_quality
# adjust_brightness
# rgb_to_grayscale
# mediapipe ../../data/processed/mediapipe/UCF-101-Analysis-augmentation/
# rot90
# adjust_contrast
# log
# adjust_hue
# stateless_random_brightness
# adjust_jpeg_quality
# adjust_brightness
# rgb_to_grayscale
# openface ../../data/processed/openface/UCF-101-Analysis-augmentation/
# rot90
# adjust_contrast
# log
# adjust_hue
# stateless_random_brightness
# adjust_jpeg_quality
# adjust_brightness
# rgb_to_grayscale
# (2824164, 6)

# %%
2824164 + 403452
# Out:
# 3227616

# %%
df_combined_aug
# Out:
#      frame                video_name  \
# 0        1   v_BrushingTeeth_g21_c04
# 1        2   v_BrushingTeeth_g21_c04
# 2        3   v_BrushingTeeth_g21_c04
# 3        4   v_BrushingTeeth_g21_c04
# 4        5   v_BrushingTeeth_g21_c04
# ..     ...                       ...
# 176    177  v_ApplyEyeMakeup_g20_c06
# 177    178  v_ApplyEyeMakeup_g20_c06
# 178    179  v_ApplyEyeMakeup_g20_c06
# 179    180  v_ApplyEyeMakeup_g20_c06
# 180    181  v_ApplyEyeMakeup_g20_c06
#
#                                                   keys extractor  \
# 0                                                  NaN      dlib
# 1                                                  NaN      dlib
# 2                                                  NaN      dlib
# 3                                                  NaN      dlib
# 4                                                  NaN      dlib
# ..                                                 ...       ...
# 176  [[83.8, 92.9],[83.8, 110.0],[85.5, 127.1],[88....  openface
# 177  [[83.8, 94.8],[84.1, 112.2],[86.2, 129.6],[89....  openface
# 178  [[84.4, 91.4],[84.2, 108.8],[85.9, 126.2],[88....  openface
# 179  [[84.7, 89.1],[84.2, 106.6],[85.7, 124.2],[88....  openface
# 180  [[85.5, 88.7],[84.9, 106.1],[86.2, 123.6],[88....  openface
#
#                   aug           class
# 0               rot90   BrushingTeeth
# 1               rot90   BrushingTeeth
# 2               rot90   BrushingTeeth
# 3               rot90   BrushingTeeth
# 4               rot90   BrushingTeeth
# ..                ...             ...
# 176  rgb_to_grayscale  ApplyEyeMakeup
# 177  rgb_to_grayscale  ApplyEyeMakeup
# 178  rgb_to_grayscale  ApplyEyeMakeup
# 179  rgb_to_grayscale  ApplyEyeMakeup
# 180  rgb_to_grayscale  ApplyEyeMakeup
#
# [2824164 rows x 6 columns]

# %%
#Concat Augmentation and Original
        
df_combined = pd.concat([df_combined_orig, df_combined_aug], axis=0)
df_combined['na'] = np.where(df_combined['keys'].isna(), 1, 0)
df_combined.head(2)
# Out:
#    frame               video_name  \
# 0      1  v_BrushingTeeth_g21_c04
# 1      2  v_BrushingTeeth_g21_c04
#
#                                                 keys extractor       aug  \
# 0  [[70, 27], [68, 48], [69, 70], [75, 92], [83, ...      dlib  original
# 1  [[82, 31], [80, 49], [80, 69], [84, 87], [88, ...      dlib  original
#
#            class  na
# 0  BrushingTeeth   0
# 1  BrushingTeeth   0

# %%
daa = df_combined
daa.groupby(['video_name', 'aug']).agg('count')
# Out:
#                                                       frame  keys  extractor  \
# video_name               aug
# v_ApplyEyeMakeup_g01_c01 adjust_brightness              492   144        492
#                          adjust_contrast                492   299        492
#                          adjust_hue                     492   227        492
#                          adjust_jpeg_quality            492   338        492
#                          original                       492   375        492
# ...                                                     ...   ...        ...
# v_ShavingBeard_g25_c06   adjust_jpeg_quality            705     1        705
#                          original                       705     6        705
#                          rgb_to_grayscale               705     0        705
#                          rot90                          705    13        705
#                          stateless_random_brightness    705     4        705
#
#                                                       class   na
# video_name               aug
# v_ApplyEyeMakeup_g01_c01 adjust_brightness              492  492
#                          adjust_contrast                492  492
#                          adjust_hue                     492  492
#                          adjust_jpeg_quality            492  492
#                          original                       492  492
# ...                                                     ...  ...
# v_ShavingBeard_g25_c06   adjust_jpeg_quality            705  705
#                          original                       705  705
#                          rgb_to_grayscale               705  705
#                          rot90                          705  705
#                          stateless_random_brightness    705  705
#
# [4736 rows x 5 columns]

# %%
403452*8
# Out:
# 3227616

# %%
#PRova

#df_combined['na'] = df_combined['na'].astype('category')

df_combined.loc[(df_combined.aug == 'rot90') & 
                (df_combined.extractor == 'dlib') & 
                (df_combined.video_name == 'v_ApplyEyeMakeup_g01_c01')].na.value_counts()
# Out:
# 1    164
# Name: na, dtype: int64

# %%
df_combined_filtro = df_combined.loc[#(df_combined.aug == 'rot90') & 
                (df_combined.extractor == 'dlib') #& 
                #(df_combined.video_name == 'v_ApplyEyeMakeup_g01_c01')
]

# %%
prov = df_combined_filtro.groupby(['aug', 'na', 'extractor', 'video_name'
                           ]).count().reset_index()[['aug', 'na','extractor', 'frame', 'video_name']]
df_combined_filtro.loc[(df_combined_filtro.aug == 'rot90') & 
                (df_combined_filtro.extractor == 'dlib') & 
                (df_combined_filtro.video_name == 'v_ApplyEyeMakeup_g01_c01')]
# Out:
#      frame                video_name keys extractor    aug           class  na
# 0        1  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# 1        2  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# 2        3  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# 3        4  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# 4        5  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# ..     ...                       ...  ...       ...    ...             ...  ..
# 159    160  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# 160    161  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# 161    162  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# 162    163  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
# 163    164  v_ApplyEyeMakeup_g01_c01  NaN      dlib  rot90  ApplyEyeMakeup   1
#
# [164 rows x 7 columns]

# %%
df_combined['class'].value_counts()
# Out:
# PlayingFlute      995064
# ShavingBeard      855840
# BrushingTeeth     792120
# ApplyEyeMakeup    584592
# Name: class, dtype: int64

# %%
print('Quantidade de Frames [Dlib]: '+str(df_combined.loc[df_combined.extractor == 'dlib'].shape))
print('Quantidade de Frames [Mediapipe]: '+str(df_combined.loc[df_combined.extractor == 'mediapipe'].shape))
print('Quantidade de Frames [OpenFace]: '+str(df_combined.loc[df_combined.extractor == 'openface'].shape))
# Out:
# Quantidade de Frames [Dlib]: (1075872, 7)
# Quantidade de Frames [Mediapipe]: (1075872, 7)
# Quantidade de Frames [OpenFace]: (1075872, 7)

# %%
1075872*3
# Out:
# 3227616

# %% [markdown]
# # Por Augmentation

# %%
df_combined.groupby(['extractor', 'aug']).size().reset_index(name='counts')
# Out:
#     extractor                          aug  counts
# 0        dlib            adjust_brightness  134484
# 1        dlib              adjust_contrast  134484
# 2        dlib                   adjust_hue  134484
# 3        dlib          adjust_jpeg_quality  134484
# 4        dlib                     original  134484
# 5        dlib             rgb_to_grayscale  134484
# 6        dlib                        rot90  134484
# 7        dlib  stateless_random_brightness  134484
# 8   mediapipe            adjust_brightness  134484
# 9   mediapipe              adjust_contrast  134484
# 10  mediapipe                   adjust_hue  134484
# 11  mediapipe          adjust_jpeg_quality  134484
# 12  mediapipe                     original  134484
# 13  mediapipe             rgb_to_grayscale  134484
# 14  mediapipe                        rot90  134484
# 15  mediapipe  stateless_random_brightness  134484
# 16   openface            adjust_brightness  134484
# 17   openface              adjust_contrast  134484
# 18   openface                   adjust_hue  134484
# 19   openface          adjust_jpeg_quality  134484
# 20   openface                     original  134484
# 21   openface             rgb_to_grayscale  134484
# 22   openface                        rot90  134484
# 23   openface  stateless_random_brightness  134484

# %%
label_mediapipe = 'mediapipe'
label_dlib = 'dlib'
label_openface = 'openface'

print("----- Description -----")
mdnna = (len(df_combined.loc[(df_combined.extractor == label_mediapipe) & (df_combined['keys'].notna())])/len(df_combined))
mdna = (len(df_combined.loc[(df_combined.extractor == label_mediapipe) & (df_combined['keys'].isna())])/len(df_combined))
dbnna = (len(df_combined.loc[(df_combined.extractor == label_dlib) & (df_combined['keys'].notna())])/len(df_combined))
dbna = (len(df_combined.loc[(df_combined.extractor == label_dlib) & (df_combined['keys'].isna())])/len(df_combined))
ofnna = (len(df_combined.loc[(df_combined.extractor == label_openface) & (df_combined['keys'].notna())])/len(df_combined))
ofna = (len(df_combined.loc[(df_combined.extractor == label_openface) & (df_combined['keys'].isna())])/len(df_combined))


print("Porcentagem frames com landmarks detectados Mediapipe: {:.2f}%".format(mdnna))
print("Porcentagem frames com landmarks NÃO detectados Mediapipe: {:.2f}%".format(mdna))
print("Porcentagem frames com landmarks detectados Dlib: {:.2f}%".format(dbnna))
print("Porcentagem frames com landmarks NÃO detectados Dlib: {:.2f}%".format(dbna))
print("Porcentagem frames com landmarks detectados Dlib: {:.2f}%".format(ofnna))
print("Porcentagem frames com landmarks NÃO detectados Dlib: {:.2f}%".format(ofna))
# Out:
# ----- Description -----
# Porcentagem frames com landmarks detectados Mediapipe: 0.20%
# Porcentagem frames com landmarks NÃO detectados Mediapipe: 0.13%
# Porcentagem frames com landmarks detectados Dlib: 0.08%
# Porcentagem frames com landmarks NÃO detectados Dlib: 0.25%
# Porcentagem frames com landmarks detectados Dlib: 0.15%
# Porcentagem frames com landmarks NÃO detectados Dlib: 0.18%

# %%
df_combined.groupby(['aug', 'na', 'extractor']).count().reset_index()[['aug', 'na','extractor', 'frame']]
# Out:
#                             aug  na  extractor   frame
# 0             adjust_brightness   0       dlib   40661
# 1             adjust_brightness   0  mediapipe   87629
# 2             adjust_brightness   0   openface   66011
# 3             adjust_brightness   1       dlib   93823
# 4             adjust_brightness   1  mediapipe   46855
# 5             adjust_brightness   1   openface   68473
# 6               adjust_contrast   0       dlib   35081
# 7               adjust_contrast   0  mediapipe   75504
# 8               adjust_contrast   0   openface   57887
# 9               adjust_contrast   1       dlib   99403
# 10              adjust_contrast   1  mediapipe   58980
# 11              adjust_contrast   1   openface   76597
# 12                   adjust_hue   0       dlib   45454
# 13                   adjust_hue   0  mediapipe   38457
# 14                   adjust_hue   0   openface   51904
# 15                   adjust_hue   1       dlib   89030
# 16                   adjust_hue   1  mediapipe   96027
# 17                   adjust_hue   1   openface   82580
# 18          adjust_jpeg_quality   0       dlib   31892
# 19          adjust_jpeg_quality   0  mediapipe   84919
# 20          adjust_jpeg_quality   0   openface   86607
# 21          adjust_jpeg_quality   1       dlib  102592
# 22          adjust_jpeg_quality   1  mediapipe   49565
# 23          adjust_jpeg_quality   1   openface   47877
# 24                     original   0       dlib   45776
# 25                     original   0  mediapipe  110407
# 26                     original   0   openface   91647
# 27                     original   1       dlib   88708
# 28                     original   1  mediapipe   24077
# 29                     original   1   openface   42837
# 30             rgb_to_grayscale   0       dlib   42841
# 31             rgb_to_grayscale   0  mediapipe   99262
# 32             rgb_to_grayscale   0   openface   83125
# 33             rgb_to_grayscale   1       dlib   91643
# 34             rgb_to_grayscale   1  mediapipe   35222
# 35             rgb_to_grayscale   1   openface   51359
# 36                        rot90   0       dlib     131
# 37                        rot90   0  mediapipe   88603
# 38                        rot90   0   openface   13754
# 39                        rot90   1       dlib  134353
# 40                        rot90   1  mediapipe   45881
# 41                        rot90   1   openface  120730
# 42  stateless_random_brightness   0       dlib   18962
# 43  stateless_random_brightness   0  mediapipe   61389
# 44  stateless_random_brightness   0   openface   46993
# 45  stateless_random_brightness   1       dlib  115522
# 46  stateless_random_brightness   1  mediapipe   73095
# 47  stateless_random_brightness   1   openface   87491

# %%
df_combined.loc[df_combined.aug == 'adjust_brightness'][['frame', 'video_name', 'extractor', 'aug','class','na']].to_csv("ciclo1.csv", sep=',', index=False)

# %%
df_combined.groupby(['aug', 'na', 'extractor']).count().reset_index()[['aug', 'na','extractor', 'frame']].frame.sum()
# Out:
# 3227616

# %%
def plt_bar_extract(df_combined, extractor):
    fig = plt.figure(figsize=(14,8))
    count = 1
    colors = ['green',"red", 'blue']

    df = df_combined.loc[(df_combined['extractor'] == extractor)]
    ax = sns.countplot(x="aug", hue="na", data=df, palette=colors)
    ax.set(ylabel='Total of Frames', title=extractor)
    for c in ax.containers:
        labels = [f'{w/len(df.index)*len(df.aug.unique())*100:0.1f}%' if (w := v.get_height()) > 0 else '' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    plt.xticks(rotation=20)

    
def plt_bar_extract_na(df_combined, na):
    fig = plt.figure(figsize=(14,8))
    count = 1
    colors = ['green', "red", 'blue']

    df = df_combined.loc[(df_combined['na'] == na)].reset_index()
    ax = sns.countplot(x="aug", hue="extractor", data=df, palette=colors)
    ax.set(ylabel='Total of Frames', title='Quantidade de frames com landmarks retornados (%)')
    idx_extractor=0
    for c in ax.containers:
        qt_extractores = len(df_combined.extractor.unique())
        qt_aug = len(df_combined.aug.unique())
        
        #labels = [f'{w/len(df.index)*len(df.aug.unique())*100:0.1f}%' if (w := v.get_height()) > 0 else '' for v in c]
        labels = [f'{w/((len(df_combined)/qt_extractores)/qt_aug)*100:0.1f}%' if (w := v.get_height()) > 0 else '' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
        idx_extractor=idx_extractor+1
        
    plt.xticks(rotation=20)

# %%
plt_bar_extract(df_combined,  'mediapipe')
plt_bar_extract(df_combined,  'dlib')
plt_bar_extract(df_combined,  'openface')

# %%
plt_bar_extract_na(df_combined,  0)

# %%
dados = df_combined.groupby(['extractor', 'aug', 'na']).size().reset_index(name='counts')
dados.loc[dados.na == 1]
# Out:
#     extractor                          aug  na  counts
# 1        dlib            adjust_brightness   1   93823
# 3        dlib              adjust_contrast   1   99403
# 5        dlib                   adjust_hue   1   89030
# 7        dlib          adjust_jpeg_quality   1  102592
# 9        dlib                     original   1   88708
# 11       dlib             rgb_to_grayscale   1   91643
# 13       dlib                        rot90   1  134353
# 15       dlib  stateless_random_brightness   1  115522
# 17  mediapipe            adjust_brightness   1   46855
# 19  mediapipe              adjust_contrast   1   58980
# 21  mediapipe                   adjust_hue   1   96027
# 23  mediapipe          adjust_jpeg_quality   1   49565
# 25  mediapipe                     original   1   24077
# 27  mediapipe             rgb_to_grayscale   1   35222
# 29  mediapipe                        rot90   1   45881
# 31  mediapipe  stateless_random_brightness   1   73095
# 33   openface            adjust_brightness   1   68473
# 35   openface              adjust_contrast   1   76597
# 37   openface                   adjust_hue   1   82580
# 39   openface          adjust_jpeg_quality   1   47877
# 41   openface                     original   1   42837
# 43   openface             rgb_to_grayscale   1   51359
# 45   openface                        rot90   1  120730
# 47   openface  stateless_random_brightness   1   87491

# %%
print(dados.loc[dados.na == 1].counts.sum())
print(dados.loc[dados.na == 0].counts.sum())
# Out:
# 1822720
# 1404896

# %%
df_combined
# Out:
#      frame                video_name  \
# 0        1   v_BrushingTeeth_g21_c04
# 1        2   v_BrushingTeeth_g21_c04
# 2        3   v_BrushingTeeth_g21_c04
# 3        4   v_BrushingTeeth_g21_c04
# 4        5   v_BrushingTeeth_g21_c04
# ..     ...                       ...
# 176    177  v_ApplyEyeMakeup_g20_c06
# 177    178  v_ApplyEyeMakeup_g20_c06
# 178    179  v_ApplyEyeMakeup_g20_c06
# 179    180  v_ApplyEyeMakeup_g20_c06
# 180    181  v_ApplyEyeMakeup_g20_c06
#
#                                                   keys extractor  \
# 0    [[70, 27], [68, 48], [69, 70], [75, 92], [83, ...      dlib
# 1    [[82, 31], [80, 49], [80, 69], [84, 87], [88, ...      dlib
# 2    [[77, 28], [75, 47], [76, 68], [80, 88], [86, ...      dlib
# 3    [[79, 30], [77, 48], [77, 68], [81, 88], [86, ...      dlib
# 4    [[77, 28], [75, 45], [75, 65], [79, 85], [83, ...      dlib
# ..                                                 ...       ...
# 176  [[83.8, 92.9],[83.8, 110.0],[85.5, 127.1],[88....  openface
# 177  [[83.8, 94.8],[84.1, 112.2],[86.2, 129.6],[89....  openface
# 178  [[84.4, 91.4],[84.2, 108.8],[85.9, 126.2],[88....  openface
# 179  [[84.7, 89.1],[84.2, 106.6],[85.7, 124.2],[88....  openface
# 180  [[85.5, 88.7],[84.9, 106.1],[86.2, 123.6],[88....  openface
#
#                   aug           class  na
# 0            original   BrushingTeeth   0
# 1            original   BrushingTeeth   0
# 2            original   BrushingTeeth   0
# 3            original   BrushingTeeth   0
# 4            original   BrushingTeeth   0
# ..                ...             ...  ..
# 176  rgb_to_grayscale  ApplyEyeMakeup   0
# 177  rgb_to_grayscale  ApplyEyeMakeup   0
# 178  rgb_to_grayscale  ApplyEyeMakeup   0
# 179  rgb_to_grayscale  ApplyEyeMakeup   0
# 180  rgb_to_grayscale  ApplyEyeMakeup   0
#
# [3227616 rows x 7 columns]

# %% [markdown]
# # Diferença do Augmentation para a base Original

# %%
def diff_calcule(df_combined):
    
    df_diff_ofc = pd.DataFrame()
    
    for i in df_combined['extractor'].unique():
        df = df_combined.loc[(df_combined['extractor'] == i)]
        df_diff = pd.crosstab(df['aug'],df['na']).apply(lambda r: r/r.sum(), axis=1).reset_index()

        ## Diferença de porcentagem
        ref_origin =  df_diff.loc[df_diff.aug == 'original'].reset_index().at[0,0] #index, col
        print(ref_origin)

        df_diff['diff_original'] = df_diff[0] - ref_origin
        df_diff['extractor'] = i
        df_diff.rename(columns={0:'notna'}, inplace=True)
        del df_diff[1]
        
        df_diff_ofc = pd.concat([df_diff_ofc, df_diff], axis=0)
    
    return df_diff_ofc

# %%
df_diff = diff_calcule(df_combined)
df_diff
# Out:
# 0.3403824990333423
# 0.8209675500431278
# 0.6814714018024449
# na                          aug     notna  diff_original  extractor
# 0             adjust_brightness  0.302348      -0.038034       dlib
# 1               adjust_contrast  0.260856      -0.079526       dlib
# 2                    adjust_hue  0.337988      -0.002394       dlib
# 3           adjust_jpeg_quality  0.237143      -0.103239       dlib
# 4                      original  0.340382       0.000000       dlib
# 5              rgb_to_grayscale  0.318558      -0.021824       dlib
# 6                         rot90  0.000974      -0.339408       dlib
# 7   stateless_random_brightness  0.140998      -0.199384       dlib
# 0             adjust_brightness  0.651594      -0.169373  mediapipe
# 1               adjust_contrast  0.561435      -0.259533  mediapipe
# 2                    adjust_hue  0.285960      -0.535008  mediapipe
# 3           adjust_jpeg_quality  0.631443      -0.189524  mediapipe
# 4                      original  0.820968       0.000000  mediapipe
# 5              rgb_to_grayscale  0.738095      -0.082872  mediapipe
# 6                         rot90  0.658837      -0.162131  mediapipe
# 7   stateless_random_brightness  0.456478      -0.364489  mediapipe
# 0             adjust_brightness  0.490846      -0.190625   openface
# 1               adjust_contrast  0.430438      -0.251034   openface
# 2                    adjust_hue  0.385949      -0.295522   openface
# 3           adjust_jpeg_quality  0.643995      -0.037477   openface
# 4                      original  0.681471       0.000000   openface
# 5              rgb_to_grayscale  0.618103      -0.063368   openface
# 6                         rot90  0.102272      -0.579199   openface
# 7   stateless_random_brightness  0.349432      -0.332039   openface

# %%
df_diff.reset_index().copy()
# Out:
# na  index                          aug     notna  diff_original  extractor
# 0       0            adjust_brightness  0.302348      -0.038034       dlib
# 1       1              adjust_contrast  0.260856      -0.079526       dlib
# 2       2                   adjust_hue  0.337988      -0.002394       dlib
# 3       3          adjust_jpeg_quality  0.237143      -0.103239       dlib
# 4       4                     original  0.340382       0.000000       dlib
# 5       5             rgb_to_grayscale  0.318558      -0.021824       dlib
# 6       6                        rot90  0.000974      -0.339408       dlib
# 7       7  stateless_random_brightness  0.140998      -0.199384       dlib
# 8       0            adjust_brightness  0.651594      -0.169373  mediapipe
# 9       1              adjust_contrast  0.561435      -0.259533  mediapipe
# 10      2                   adjust_hue  0.285960      -0.535008  mediapipe
# 11      3          adjust_jpeg_quality  0.631443      -0.189524  mediapipe
# 12      4                     original  0.820968       0.000000  mediapipe
# 13      5             rgb_to_grayscale  0.738095      -0.082872  mediapipe
# 14      6                        rot90  0.658837      -0.162131  mediapipe
# 15      7  stateless_random_brightness  0.456478      -0.364489  mediapipe
# 16      0            adjust_brightness  0.490846      -0.190625   openface
# 17      1              adjust_contrast  0.430438      -0.251034   openface
# 18      2                   adjust_hue  0.385949      -0.295522   openface
# 19      3          adjust_jpeg_quality  0.643995      -0.037477   openface
# 20      4                     original  0.681471       0.000000   openface
# 21      5             rgb_to_grayscale  0.618103      -0.063368   openface
# 22      6                        rot90  0.102272      -0.579199   openface
# 23      7  stateless_random_brightness  0.349432      -0.332039   openface

# %%
fig = plt.figure(figsize=(14,8))
count = 1
colors = ['green', "red", 'blue']
ax = sns.barplot(x="aug", y="diff_original", hue="extractor", data=df_diff, palette=colors)
ax.set(ylabel='Total of Frames', title='Diferença de Frames com Features Detectadas (base: Original)')

for c in ax.containers:
    labels = [f'{w*100:0.1f}%' if (w := v.get_height()) < 0 else '' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')
    
plt.xticks(rotation=20)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'adjust_brightness'),
#   Text(1, 0, 'adjust_contrast'),
#   Text(2, 0, 'adjust_hue'),
#   Text(3, 0, 'adjust_jpeg_quality'),
#   Text(4, 0, 'original'),
#   Text(5, 0, 'rgb_to_grayscale'),
#   Text(6, 0, 'rot90'),
#   Text(7, 0, 'stateless_random_brightness')])

# %% [markdown]
# ## Análise dos Gráficos
#
# Ao considerar a diferença de quantidade de frames com landmarks detectados entre a base original e as variações de data augmentation, é possível perceber que o extrator Mediapipe é mais sensível ao ajuste de hue (matiz/tonalidade), redução de brilho e ajuste de contraste.
#
# Já o Dlib é muito sensível quando os dados estão rotacionados a 90° e podemos considerar que, ao observar os dados analisados, o Dlib é pouco sensível a dados com ajuste de hue (matiz/tonalidade) e escala de cinza.

# %%
def get_total_frames_unit(video, ext, aug, total_frames):
    return total_frames.loc[(total_frames.video_name == video) & 
                            (total_frames.extractor == ext) & 
                            (total_frames.aug == aug)].reset_index().at[0,'total_frames'] #index, col

# %%
df_combined
# Out:
#      frame                video_name  \
# 0        1   v_BrushingTeeth_g21_c04
# 1        2   v_BrushingTeeth_g21_c04
# 2        3   v_BrushingTeeth_g21_c04
# 3        4   v_BrushingTeeth_g21_c04
# 4        5   v_BrushingTeeth_g21_c04
# ..     ...                       ...
# 176    177  v_ApplyEyeMakeup_g20_c06
# 177    178  v_ApplyEyeMakeup_g20_c06
# 178    179  v_ApplyEyeMakeup_g20_c06
# 179    180  v_ApplyEyeMakeup_g20_c06
# 180    181  v_ApplyEyeMakeup_g20_c06
#
#                                                   keys extractor  \
# 0    [[70, 27], [68, 48], [69, 70], [75, 92], [83, ...      dlib
# 1    [[82, 31], [80, 49], [80, 69], [84, 87], [88, ...      dlib
# 2    [[77, 28], [75, 47], [76, 68], [80, 88], [86, ...      dlib
# 3    [[79, 30], [77, 48], [77, 68], [81, 88], [86, ...      dlib
# 4    [[77, 28], [75, 45], [75, 65], [79, 85], [83, ...      dlib
# ..                                                 ...       ...
# 176  [[83.8, 92.9],[83.8, 110.0],[85.5, 127.1],[88....  openface
# 177  [[83.8, 94.8],[84.1, 112.2],[86.2, 129.6],[89....  openface
# 178  [[84.4, 91.4],[84.2, 108.8],[85.9, 126.2],[88....  openface
# 179  [[84.7, 89.1],[84.2, 106.6],[85.7, 124.2],[88....  openface
# 180  [[85.5, 88.7],[84.9, 106.1],[86.2, 123.6],[88....  openface
#
#                   aug           class  na
# 0            original   BrushingTeeth   0
# 1            original   BrushingTeeth   0
# 2            original   BrushingTeeth   0
# 3            original   BrushingTeeth   0
# 4            original   BrushingTeeth   0
# ..                ...             ...  ..
# 176  rgb_to_grayscale  ApplyEyeMakeup   0
# 177  rgb_to_grayscale  ApplyEyeMakeup   0
# 178  rgb_to_grayscale  ApplyEyeMakeup   0
# 179  rgb_to_grayscale  ApplyEyeMakeup   0
# 180  rgb_to_grayscale  ApplyEyeMakeup   0
#
# [3227616 rows x 7 columns]

# %% [markdown]
# ## [Fix] Zero counts solved

# %%
#Considerando valores zerados
#https://github.com/pandas-dev/pandas/issues/8559

df_combined['na'] = df_combined['na'].astype('category')

df_combined.loc[(df_combined.aug == 'rot90') & 
                (df_combined.extractor == 'dlib') & 
                (df_combined.video_name == 'v_ApplyEyeMakeup_g01_c01')].na.value_counts()
# Out:
# 1    164
# 0      0
# Name: na, dtype: int64

# %%
df_combined.shape
# Out:
# (3227616, 7)

# %%
#Na análise anterior não era considerados v[ídeos que tinham todo seu corpo com frme retornado]
#tenho que ter uma linha 
#v_ApplyEyeMakeup_g01_c01	dlib	rot90	ApplyEyeMakeup	0	0	164	0.0

# %%
s = pd.Series(['a','b','a','c','d','c'])
count_str = s[s.isin(['a','u'])].value_counts()
print(count_str)
# Out:
# a    2
# dtype: int64

# %%
count_cat = s.astype('category')[s.isin(['a','u'])].value_counts()
print(count_cat)
# Out:
# a    2
# b    0
# c    0
# d    0
# dtype: int64

# %%
total_frames = df_combined.groupby(['video_name', 'extractor', 'aug']).size().reset_index(name='total_frames')
df_diff_unit = df_combined.groupby(['video_name', 'extractor', 'aug', 'na']).size().reset_index(name='counts_NAs')

display(df_diff_unit.loc[#(df_diff_unit.aug == 'rot90') & 
                #(df_diff_unit.extractor == 'dlib') & 
                (df_diff_unit.video_name == 'v_ApplyEyeMakeup_g01_c01')])

#continua
# Out:
#                   video_name  extractor                          aug na  \
# 0   v_ApplyEyeMakeup_g01_c01       dlib            adjust_brightness  0
# 1   v_ApplyEyeMakeup_g01_c01       dlib            adjust_brightness  1
# 2   v_ApplyEyeMakeup_g01_c01       dlib              adjust_contrast  0
# 3   v_ApplyEyeMakeup_g01_c01       dlib              adjust_contrast  1
# 4   v_ApplyEyeMakeup_g01_c01       dlib                   adjust_hue  0
# 5   v_ApplyEyeMakeup_g01_c01       dlib                   adjust_hue  1
# 6   v_ApplyEyeMakeup_g01_c01       dlib          adjust_jpeg_quality  0
# 7   v_ApplyEyeMakeup_g01_c01       dlib          adjust_jpeg_quality  1
# 8   v_ApplyEyeMakeup_g01_c01       dlib                     original  0
# 9   v_ApplyEyeMakeup_g01_c01       dlib                     original  1
# 10  v_ApplyEyeMakeup_g01_c01       dlib             rgb_to_grayscale  0
# 11  v_ApplyEyeMakeup_g01_c01       dlib             rgb_to_grayscale  1
# 12  v_ApplyEyeMakeup_g01_c01       dlib                        rot90  0
# 13  v_ApplyEyeMakeup_g01_c01       dlib                        rot90  1
# 14  v_ApplyEyeMakeup_g01_c01       dlib  stateless_random_brightness  0
# 15  v_ApplyEyeMakeup_g01_c01       dlib  stateless_random_brightness  1
# 16  v_ApplyEyeMakeup_g01_c01  mediapipe            adjust_brightness  0
# 17  v_ApplyEyeMakeup_g01_c01  mediapipe            adjust_brightness  1
# 18  v_ApplyEyeMakeup_g01_c01  mediapipe              adjust_contrast  0
# 19  v_ApplyEyeMakeup_g01_c01  mediapipe              adjust_contrast  1
# 20  v_ApplyEyeMakeup_g01_c01  mediapipe                   adjust_hue  0
# 21  v_ApplyEyeMakeup_g01_c01  mediapipe                   adjust_hue  1
# 22  v_ApplyEyeMakeup_g01_c01  mediapipe          adjust_jpeg_quality  0
# 23  v_ApplyEyeMakeup_g01_c01  mediapipe          adjust_jpeg_quality  1
# 24  v_ApplyEyeMakeup_g01_c01  mediapipe                     original  0
# 25  v_ApplyEyeMakeup_g01_c01  mediapipe                     original  1
# 26  v_ApplyEyeMakeup_g01_c01  mediapipe             rgb_to_grayscale  0
# 27  v_ApplyEyeMakeup_g01_c01  mediapipe             rgb_to_grayscale  1
# 28  v_ApplyEyeMakeup_g01_c01  mediapipe                        rot90  0
# 29  v_ApplyEyeMakeup_g01_c01  mediapipe                        rot90  1
# 30  v_ApplyEyeMakeup_g01_c01  mediapipe  stateless_random_brightness  0
# 31  v_ApplyEyeMakeup_g01_c01  mediapipe  stateless_random_brightness  1
# 32  v_ApplyEyeMakeup_g01_c01   openface            adjust_brightness  0
# 33  v_ApplyEyeMakeup_g01_c01   openface            adjust_brightness  1
# 34  v_ApplyEyeMakeup_g01_c01   openface              adjust_contrast  0
# 35  v_ApplyEyeMakeup_g01_c01   openface              adjust_contrast  1
# 36  v_ApplyEyeMakeup_g01_c01   openface                   adjust_hue  0
# 37  v_ApplyEyeMakeup_g01_c01   openface                   adjust_hue  1
# 38  v_ApplyEyeMakeup_g01_c01   openface          adjust_jpeg_quality  0
# 39  v_ApplyEyeMakeup_g01_c01   openface          adjust_jpeg_quality  1
# 40  v_ApplyEyeMakeup_g01_c01   openface                     original  0
# 41  v_ApplyEyeMakeup_g01_c01   openface                     original  1
# 42  v_ApplyEyeMakeup_g01_c01   openface             rgb_to_grayscale  0
# 43  v_ApplyEyeMakeup_g01_c01   openface             rgb_to_grayscale  1
# 44  v_ApplyEyeMakeup_g01_c01   openface                        rot90  0
# 45  v_ApplyEyeMakeup_g01_c01   openface                        rot90  1
# 46  v_ApplyEyeMakeup_g01_c01   openface  stateless_random_brightness  0
# 47  v_ApplyEyeMakeup_g01_c01   openface  stateless_random_brightness  1
#
#     counts_NAs
# 0            8
# 1          156
# 2           42
# 3          122
# 4           63
# 5          101
# 6           40
# 7          124
# 8           64
# 9          100
# 10          57
# 11         107
# 12           0
# 13         164
# 14          36
# 15         128
# 16         104
# 17          60
# 18         127
# 19          37
# 20          55
# 21         109
# 22         142
# 23          22
# 24         151
# 25          13
# 26         136
# 27          28
# 28         136
# 29          28
# 30         146
# 31          18
# 32          32
# 33         132
# 34         130
# 35          34
# 36         109
# 37          55
# 38         156
# 39           8
# 40         160
# 41           4
# 42         143
# 43          21
# 44          30
# 45         134
# 46         135
# 47          29

# %%
#CASO
#12	v_ApplyEyeMakeup_g01_c01	dlib	rot90	0	0
#13	v_ApplyEyeMakeup_g01_c01	dlib	rot90	1	164

# %%
# CASO
gg = df_diff_unit.groupby(['video_name', 'extractor']).sum()
gg['counts_NAs'] = gg['counts_NAs'].astype(str)
gg = gg.groupby(['video_name', 'counts_NAs'])['counts_NAs'].count().reset_index(name='total')
gg.loc[gg.total != 3]
# Out:
# Empty DataFrame
# Columns: [video_name, counts_NAs, total]
# Index: []

# %%
df_diff_unit['total_frames'] = df_diff_unit.apply(lambda x: get_total_frames_unit(x['video_name'], x['extractor'], x['aug'], total_frames), axis=1)
df_diff_unit['percent_NAs'] = df_diff_unit['counts_NAs']/df_diff_unit['total_frames']
df_diff_unit['percent_NAs'] = round(df_diff_unit['percent_NAs']*100, 2)

df_diff_unit.loc[(df_diff_unit.extractor == 'dlib') &
((df_diff_unit.video_name == 'v_ApplyEyeMakeup_g01_c02') |
(df_diff_unit.video_name == 'v_ApplyEyeMakeup_g01_c01') |
(df_diff_unit.video_name == 'v_PlayingFlute_g05_c04') |
(df_diff_unit.video_name == 'v_ShavingBeard_g16_c02'))]
# Out:
#                      video_name extractor                          aug na  \
# 0      v_ApplyEyeMakeup_g01_c01      dlib            adjust_brightness  0
# 1      v_ApplyEyeMakeup_g01_c01      dlib            adjust_brightness  1
# 2      v_ApplyEyeMakeup_g01_c01      dlib              adjust_contrast  0
# 3      v_ApplyEyeMakeup_g01_c01      dlib              adjust_contrast  1
# 4      v_ApplyEyeMakeup_g01_c01      dlib                   adjust_hue  0
# ...                         ...       ...                          ... ..
# 25211    v_ShavingBeard_g16_c02      dlib             rgb_to_grayscale  1
# 25212    v_ShavingBeard_g16_c02      dlib                        rot90  0
# 25213    v_ShavingBeard_g16_c02      dlib                        rot90  1
# 25214    v_ShavingBeard_g16_c02      dlib  stateless_random_brightness  0
# 25215    v_ShavingBeard_g16_c02      dlib  stateless_random_brightness  1
#
#        counts_NAs  total_frames  percent_NAs
# 0               8           164         4.88
# 1             156           164        95.12
# 2              42           164        25.61
# 3             122           164        74.39
# 4              63           164        38.41
# ...           ...           ...          ...
# 25211           0           264         0.00
# 25212           0           264         0.00
# 25213         264           264       100.00
# 25214           0           264         0.00
# 25215         264           264       100.00
#
# [64 rows x 7 columns]

# %%
# CASO
gg = df_diff_unit[['video_name', 
                   'extractor', 
                   'aug', 
                   'na', 
                   'percent_NAs']].groupby(['video_name', 'extractor', 'aug']).sum().reset_index()

gg['percent_NAs'] = gg['percent_NAs'].astype(float)
gg.loc[gg.percent_NAs != 100]
#gg['counts_notna'] = gg['counts_notna'].astype(str)
#gg = gg.groupby(['video_name', 'counts_notna'])['counts_notna'].count().reset_index(name='total')
#gg.loc[gg.total != 3]
# Out:
#                    video_name extractor    aug  percent_NAs
# 11566  v_ShavingBeard_g09_c01  openface  rot90       100.01

# %%
# CASO
gg = gg.groupby(['video_name', 'aug', 'percent_NAs'])['percent_NAs'].count().reset_index(name='total')
gg.loc[gg.total != 3]
# Out:
#                   video_name    aug  percent_NAs  total
# 3854  v_ShavingBeard_g09_c01  rot90       100.00      2
# 3855  v_ShavingBeard_g09_c01  rot90       100.01      1

# %%
gg.percent_NAs.value_counts()
# Out:
# 100.00    4736
# 100.01       1
# Name: percent_NAs, dtype: int64

# %%
# CASO
df_diff_unit.loc[df_diff_unit.video_name == 'v_ShavingBeard_g09_c01']
# Out:
#                    video_name  extractor                          aug na  \
# 23088  v_ShavingBeard_g09_c01       dlib            adjust_brightness  0
# 23089  v_ShavingBeard_g09_c01       dlib            adjust_brightness  1
# 23090  v_ShavingBeard_g09_c01       dlib              adjust_contrast  0
# 23091  v_ShavingBeard_g09_c01       dlib              adjust_contrast  1
# 23092  v_ShavingBeard_g09_c01       dlib                   adjust_hue  0
# 23093  v_ShavingBeard_g09_c01       dlib                   adjust_hue  1
# 23094  v_ShavingBeard_g09_c01       dlib          adjust_jpeg_quality  0
# 23095  v_ShavingBeard_g09_c01       dlib          adjust_jpeg_quality  1
# 23096  v_ShavingBeard_g09_c01       dlib                     original  0
# 23097  v_ShavingBeard_g09_c01       dlib                     original  1
# 23098  v_ShavingBeard_g09_c01       dlib             rgb_to_grayscale  0
# 23099  v_ShavingBeard_g09_c01       dlib             rgb_to_grayscale  1
# 23100  v_ShavingBeard_g09_c01       dlib                        rot90  0
# 23101  v_ShavingBeard_g09_c01       dlib                        rot90  1
# 23102  v_ShavingBeard_g09_c01       dlib  stateless_random_brightness  0
# 23103  v_ShavingBeard_g09_c01       dlib  stateless_random_brightness  1
# 23104  v_ShavingBeard_g09_c01  mediapipe            adjust_brightness  0
# 23105  v_ShavingBeard_g09_c01  mediapipe            adjust_brightness  1
# 23106  v_ShavingBeard_g09_c01  mediapipe              adjust_contrast  0
# 23107  v_ShavingBeard_g09_c01  mediapipe              adjust_contrast  1
# 23108  v_ShavingBeard_g09_c01  mediapipe                   adjust_hue  0
# 23109  v_ShavingBeard_g09_c01  mediapipe                   adjust_hue  1
# 23110  v_ShavingBeard_g09_c01  mediapipe          adjust_jpeg_quality  0
# 23111  v_ShavingBeard_g09_c01  mediapipe          adjust_jpeg_quality  1
# 23112  v_ShavingBeard_g09_c01  mediapipe                     original  0
# 23113  v_ShavingBeard_g09_c01  mediapipe                     original  1
# 23114  v_ShavingBeard_g09_c01  mediapipe             rgb_to_grayscale  0
# 23115  v_ShavingBeard_g09_c01  mediapipe             rgb_to_grayscale  1
# 23116  v_ShavingBeard_g09_c01  mediapipe                        rot90  0
# 23117  v_ShavingBeard_g09_c01  mediapipe                        rot90  1
# 23118  v_ShavingBeard_g09_c01  mediapipe  stateless_random_brightness  0
# 23119  v_ShavingBeard_g09_c01  mediapipe  stateless_random_brightness  1
# 23120  v_ShavingBeard_g09_c01   openface            adjust_brightness  0
# 23121  v_ShavingBeard_g09_c01   openface            adjust_brightness  1
# 23122  v_ShavingBeard_g09_c01   openface              adjust_contrast  0
# 23123  v_ShavingBeard_g09_c01   openface              adjust_contrast  1
# 23124  v_ShavingBeard_g09_c01   openface                   adjust_hue  0
# 23125  v_ShavingBeard_g09_c01   openface                   adjust_hue  1
# 23126  v_ShavingBeard_g09_c01   openface          adjust_jpeg_quality  0
# 23127  v_ShavingBeard_g09_c01   openface          adjust_jpeg_quality  1
# 23128  v_ShavingBeard_g09_c01   openface                     original  0
# 23129  v_ShavingBeard_g09_c01   openface                     original  1
# 23130  v_ShavingBeard_g09_c01   openface             rgb_to_grayscale  0
# 23131  v_ShavingBeard_g09_c01   openface             rgb_to_grayscale  1
# 23132  v_ShavingBeard_g09_c01   openface                        rot90  0
# 23133  v_ShavingBeard_g09_c01   openface                        rot90  1
# 23134  v_ShavingBeard_g09_c01   openface  stateless_random_brightness  0
# 23135  v_ShavingBeard_g09_c01   openface  stateless_random_brightness  1
#
#        counts_NAs  total_frames  percent_NAs
# 23088           0           160         0.00
# 23089         160           160       100.00
# 23090           0           160         0.00
# 23091         160           160       100.00
# 23092           0           160         0.00
# 23093         160           160       100.00
# 23094           0           160         0.00
# 23095         160           160       100.00
# 23096           0           160         0.00
# 23097         160           160       100.00
# 23098           0           160         0.00
# 23099         160           160       100.00
# 23100           0           160         0.00
# 23101         160           160       100.00
# 23102           0           160         0.00
# 23103         160           160       100.00
# 23104         160           160       100.00
# 23105           0           160         0.00
# 23106         160           160       100.00
# 23107           0           160         0.00
# 23108         144           160        90.00
# 23109          16           160        10.00
# 23110         160           160       100.00
# 23111           0           160         0.00
# 23112         160           160       100.00
# 23113           0           160         0.00
# 23114         160           160       100.00
# 23115           0           160         0.00
# 23116         160           160       100.00
# 23117           0           160         0.00
# 23118         160           160       100.00
# 23119           0           160         0.00
# 23120         160           160       100.00
# 23121           0           160         0.00
# 23122         160           160       100.00
# 23123           0           160         0.00
# 23124           0           160         0.00
# 23125         160           160       100.00
# 23126         160           160       100.00
# 23127           0           160         0.00
# 23128         160           160       100.00
# 23129           0           160         0.00
# 23130          52           160        32.50
# 23131         108           160        67.50
# 23132          49           160        30.63
# 23133         111           160        69.38
# 23134         104           160        65.00
# 23135          56           160        35.00

# %%
# MUDANÇA VIDEO ERROR PROPORCIONAL
df_diff_unit = df_diff_unit.loc[df_diff_unit.na == 1].reset_index()

# %%
print(df_diff_unit.loc[df_diff_unit.na == 0].shape)
print(df_diff_unit.loc[df_diff_unit.na == 1].shape)
# Out:
# (0, 8)
# (14208, 8)

# %%
df_diff_unit.loc[df_diff_unit.total_frames == df_diff_unit.counts_NAs]
# Out:
#        index                video_name extractor                          aug  \
# 6         13  v_ApplyEyeMakeup_g01_c01      dlib                        rot90
# 30        61  v_ApplyEyeMakeup_g01_c02      dlib                        rot90
# 54       109  v_ApplyEyeMakeup_g01_c03      dlib                        rot90
# 64       129  v_ApplyEyeMakeup_g01_c03  openface            adjust_brightness
# 78       157  v_ApplyEyeMakeup_g01_c04      dlib                        rot90
# ...      ...                       ...       ...                          ...
# 14201  28403    v_ShavingBeard_g25_c06  openface              adjust_contrast
# 14202  28405    v_ShavingBeard_g25_c06  openface                   adjust_hue
# 14204  28409    v_ShavingBeard_g25_c06  openface                     original
# 14205  28411    v_ShavingBeard_g25_c06  openface             rgb_to_grayscale
# 14207  28415    v_ShavingBeard_g25_c06  openface  stateless_random_brightness
#
#       na  counts_NAs  total_frames  percent_NAs
# 6      1         164           164        100.0
# 30     1         123           123        100.0
# 54     1         259           259        100.0
# 64     1         259           259        100.0
# 78     1         235           235        100.0
# ...   ..         ...           ...          ...
# 14201  1         235           235        100.0
# 14202  1         235           235        100.0
# 14204  1         235           235        100.0
# 14205  1         235           235        100.0
# 14207  1         235           235        100.0
#
# [4530 rows x 8 columns]

# %%
print(df_diff_unit.loc[df_diff_unit.percent_NAs == 1].shape)
print(df_diff_unit.loc[(df_diff_unit.percent_NAs == 50) & (df_diff_unit.na == 1)].shape)
# Out:
# (5, 8)
# (4, 8)

# %%
df_diff_unit.loc[(df_diff_unit.percent_NAs == 50) & (df_diff_unit.na == 0)]
# Out:
# Empty DataFrame
# Columns: [index, video_name, extractor, aug, na, counts_NAs, total_frames, percent_NAs]
# Index: []

# %% [markdown]
# ### [FIX] Representa 5% dos dados

# %%
print(df_diff_unit.percent_NAs.min())
print(df_diff_unit.percent_NAs.max())
# Out:
# 0.0
# 100.0

# %%
df_diff_unit.na.value_counts()
# Out:
# 1    14208
# 0        0
# Name: na, dtype: int64

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'rot90') & 
                (df_diff_unit.extractor == 'dlib') & 
                (df_diff_unit.video_name == 'v_ApplyEyeMakeup_g01_c01')]
# Out:
#    index                video_name extractor    aug na  counts_NAs  \
# 6     13  v_ApplyEyeMakeup_g01_c01      dlib  rot90  1         164
#
#    total_frames  percent_NAs
# 6           164        100.0

# %%
#df_diff_unit.groupby(['video_name', 'extractor', 'aug', 'na']).agg('count')

df_diff_unit

#data_stats.to_csv("../data/outputs/Videos-Emely-Extra/predicts_squeezenet/f1_estimation_stats.csv", sep=',', index=False)
# Out:
#        index                video_name extractor                          aug  \
# 0          1  v_ApplyEyeMakeup_g01_c01      dlib            adjust_brightness
# 1          3  v_ApplyEyeMakeup_g01_c01      dlib              adjust_contrast
# 2          5  v_ApplyEyeMakeup_g01_c01      dlib                   adjust_hue
# 3          7  v_ApplyEyeMakeup_g01_c01      dlib          adjust_jpeg_quality
# 4          9  v_ApplyEyeMakeup_g01_c01      dlib                     original
# ...      ...                       ...       ...                          ...
# 14203  28407    v_ShavingBeard_g25_c06  openface          adjust_jpeg_quality
# 14204  28409    v_ShavingBeard_g25_c06  openface                     original
# 14205  28411    v_ShavingBeard_g25_c06  openface             rgb_to_grayscale
# 14206  28413    v_ShavingBeard_g25_c06  openface                        rot90
# 14207  28415    v_ShavingBeard_g25_c06  openface  stateless_random_brightness
#
#       na  counts_NAs  total_frames  percent_NAs
# 0      1         156           164        95.12
# 1      1         122           164        74.39
# 2      1         101           164        61.59
# 3      1         124           164        75.61
# 4      1         100           164        60.98
# ...   ..         ...           ...          ...
# 14203  1         234           235        99.57
# 14204  1         235           235       100.00
# 14205  1         235           235       100.00
# 14206  1         224           235        95.32
# 14207  1         235           235       100.00
#
# [14208 rows x 8 columns]

# %%
fig = plt.figure(figsize=(14,8))

ax =  sns.displot(
    df_diff_unit, x="percent_NAs", col="extractor", row="aug",
    binwidth=3, height=5, facet_kws=dict(margin_titles=True),
)
ax.set(ylabel='Total of Frames with Landmarks')

# %%
g = sns.FacetGrid(df_diff_unit, col='aug',col_wrap=2)
#                                               change this to 4 ^
g.map(sns.boxplot,'extractor','percent_NAs',palette='muted', order=['mediapipe', 'dlib', 'openface'])
for ax in g.axes.flatten(): 
    ax.tick_params(labelbottom=True)
plt.tight_layout()
plt.show()

# %%
#Ao analisar a figura acima, temos que para o dataset original quando submetido ao extrator Dlib, há uma concentração de outliers considerável abaixo 70%, ou seja, de vídeos em que a porcentagem da quantidade de seus frames com landmarks detectados foi menor que 70%.

#Embora o Mediapipe tenha uma quantidade de frames detectados muito maior que o Dlib. Ao avaliar por vídeo (a unidade) e realizar um processamento de forma que para cada linha (vídeo) para encontrar a porcentagem de frames detectados nesse mesmo vídeo. Podemos ver que no Dlib, há um número considerável de outliers abaixo de 70%, isto é, há um número considerável de vídeos específicos em que o total de seus frames com landmarks detectados são abaixo de 70%.

#Resumindo, mas não concluindo. Talvez se não existissem "alguns vídeos específicos" o Dlib pode melhorar bastante a detecção de landmarks. Hipótese: Talvez "esses vídeos específicos" que tem 70% do seu corpo sem landmarks detectados, seja pelo fato de terem alguma característica em comum que deixa o Dlib sensível (como a distância da câmera ou tamanho do crop da face).

#Então vamos analisar alguns desses outliers?

#Validado (motivos):

#Ordem
#<=0.70 [0:100]
#whis=np.inf,


#16% dos dados podem ser considerados outliers...
#Qual o valor default para delimitar o que é um outlier ou não

# %%
fig = plt.figure(figsize=(14,8))

ax = sns.boxplot(x="aug", y="percent_NAs", data=df_diff_unit, hue="extractor")
#ax = sns.stripplot(x="aug", y="percent_notna", data=df_diff_unit, color=".3", hue="extractor")

# %%
fig = plt.figure(figsize=(14,8))

ax = sns.boxplot(x="aug", y="percent_NAs", data=df_diff_unit, whis=np.inf, hue="extractor")
#ax = sns.stripplot(x="aug", y="percent_notna", data=df_diff_unit, color=".3", hue="extractor")
# Out:
# /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1249: RuntimeWarning: invalid value encountered in double_scalars
#   loval = q1 - whis * stats['iqr']
# /home/jms2/anaconda3/envs/2way/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1250: RuntimeWarning: invalid value encountered in double_scalars
#   hival = q3 + whis * stats['iqr']

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 #(df_diff_unit.extractor == 'mediapipe') & 
                 (df_diff_unit.percent_NAs <= 0.70)].shape
# Out:
# (619, 8)

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'mediapipe')].percent_NAs.median()
# Out:
# 0.0

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'dlib')].percent_NAs.median()
# Out:
# 86.95500000000001

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'mediapipe')].percent_NAs.quantile(.05)
# Out:
# 0.0

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'dlib')].percent_NAs.quantile(.05)
# Out:
# 0.0

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'original') & (df_diff_unit.extractor == 'mediapipe') & (df_diff_unit.percent_NAs < 70)]
# Out:
#        index                video_name  extractor       aug na  counts_NAs  \
# 12        25  v_ApplyEyeMakeup_g01_c01  mediapipe  original  1          13
# 36        73  v_ApplyEyeMakeup_g01_c02  mediapipe  original  1           0
# 60       121  v_ApplyEyeMakeup_g01_c03  mediapipe  original  1           0
# 84       169  v_ApplyEyeMakeup_g01_c04  mediapipe  original  1           0
# 108      217  v_ApplyEyeMakeup_g01_c05  mediapipe  original  1           0
# ...      ...                       ...        ...       ... ..         ...
# 13980  27961    v_ShavingBeard_g24_c04  mediapipe  original  1           0
# 14004  28009    v_ShavingBeard_g24_c05  mediapipe  original  1           0
# 14028  28057    v_ShavingBeard_g24_c06  mediapipe  original  1           0
# 14052  28105    v_ShavingBeard_g24_c07  mediapipe  original  1           0
# 14100  28201    v_ShavingBeard_g25_c02  mediapipe  original  1         110
#
#        total_frames  percent_NAs
# 12              164         7.93
# 36              123         0.00
# 60              259         0.00
# 84              235         0.00
# 108             296         0.00
# ...             ...          ...
# 13980           268         0.00
# 14004           125         0.00
# 14028           203         0.00
# 14052           181         0.00
# 14100           226        48.67
#
# [515 rows x 8 columns]

# %% [raw]
# df_diff_unit.loc[(df_diff_unit.aug == 'original') & (df_diff_unit.extractor == 'mediapipe')].shape

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'rot90') & (df_diff_unit.extractor == 'dlib')]
# Out:
#        index                video_name extractor    aug na  counts_NAs  \
# 6         13  v_ApplyEyeMakeup_g01_c01      dlib  rot90  1         164
# 30        61  v_ApplyEyeMakeup_g01_c02      dlib  rot90  1         123
# 54       109  v_ApplyEyeMakeup_g01_c03      dlib  rot90  1         259
# 78       157  v_ApplyEyeMakeup_g01_c04      dlib  rot90  1         235
# 102      205  v_ApplyEyeMakeup_g01_c05      dlib  rot90  1         296
# ...      ...                       ...       ...    ... ..         ...
# 14094  28189    v_ShavingBeard_g25_c02      dlib  rot90  1         226
# 14118  28237    v_ShavingBeard_g25_c03      dlib  rot90  1         230
# 14142  28285    v_ShavingBeard_g25_c04      dlib  rot90  1         161
# 14166  28333    v_ShavingBeard_g25_c05      dlib  rot90  1         242
# 14190  28381    v_ShavingBeard_g25_c06      dlib  rot90  1         235
#
#        total_frames  percent_NAs
# 6               164        100.0
# 30              123        100.0
# 54              259        100.0
# 78              235        100.0
# 102             296        100.0
# ...             ...          ...
# 14094           226        100.0
# 14118           230        100.0
# 14142           161        100.0
# 14166           242        100.0
# 14190           235        100.0
#
# [592 rows x 8 columns]

# %%
ff = df_diff_unit.loc[(df_diff_unit.aug == 'original')]

ff
# Out:
#        index                video_name  extractor       aug na  counts_NAs  \
# 4          9  v_ApplyEyeMakeup_g01_c01       dlib  original  1         100
# 12        25  v_ApplyEyeMakeup_g01_c01  mediapipe  original  1          13
# 20        41  v_ApplyEyeMakeup_g01_c01   openface  original  1           4
# 28        57  v_ApplyEyeMakeup_g01_c02       dlib  original  1          31
# 36        73  v_ApplyEyeMakeup_g01_c02  mediapipe  original  1           0
# ...      ...                       ...        ...       ... ..         ...
# 14172  28345    v_ShavingBeard_g25_c05  mediapipe  original  1         242
# 14180  28361    v_ShavingBeard_g25_c05   openface  original  1         242
# 14188  28377    v_ShavingBeard_g25_c06       dlib  original  1         235
# 14196  28393    v_ShavingBeard_g25_c06  mediapipe  original  1         229
# 14204  28409    v_ShavingBeard_g25_c06   openface  original  1         235
#
#        total_frames  percent_NAs
# 4               164        60.98
# 12              164         7.93
# 20              164         2.44
# 28              123        25.20
# 36              123         0.00
# ...             ...          ...
# 14172           242       100.00
# 14180           242       100.00
# 14188           235       100.00
# 14196           235        97.45
# 14204           235       100.00
#
# [1776 rows x 8 columns]

# %% [markdown]
# # Exportação de Dados para Análise Estatística

# %%
os.listdir('../../')
# Out:
# ['README.md',
#  'src',
#  'notebooks',
#  '__init__.py',
#  'docs',
#  'reports',
#  'docker',
#  'references',
#  'requirements.txt',
#  'models',
#  'data',
#  'env']

# %%
df_diff_unit['experiment'] = df_diff_unit['extractor'] + '_' + df_diff_unit['aug']

# %%
df_diff_unit.experiment.unique()
# Out:
# array(['dlib_adjust_brightness', 'dlib_adjust_contrast',
#        'dlib_adjust_hue', 'dlib_adjust_jpeg_quality', 'dlib_original',
#        'dlib_rgb_to_grayscale', 'dlib_rot90',
#        'dlib_stateless_random_brightness', 'mediapipe_adjust_brightness',
#        'mediapipe_adjust_contrast', 'mediapipe_adjust_hue',
#        'mediapipe_adjust_jpeg_quality', 'mediapipe_original',
#        'mediapipe_rgb_to_grayscale', 'mediapipe_rot90',
#        'mediapipe_stateless_random_brightness',
#        'openface_adjust_brightness', 'openface_adjust_contrast',
#        'openface_adjust_hue', 'openface_adjust_jpeg_quality',
#        'openface_original', 'openface_rgb_to_grayscale', 'openface_rot90',
#        'openface_stateless_random_brightness'], dtype=object)

# %%
df_diff_unit[['percent_NAs','experiment']]
# Out:
#        percent_NAs                            experiment
# 0            95.12                dlib_adjust_brightness
# 1            74.39                  dlib_adjust_contrast
# 2            61.59                       dlib_adjust_hue
# 3            75.61              dlib_adjust_jpeg_quality
# 4            60.98                         dlib_original
# ...            ...                                   ...
# 14203        99.57          openface_adjust_jpeg_quality
# 14204       100.00                     openface_original
# 14205       100.00             openface_rgb_to_grayscale
# 14206        95.32                        openface_rot90
# 14207       100.00  openface_stateless_random_brightness
#
# [14208 rows x 2 columns]

# %%
df_diff_unit[['percent_NAs','experiment']].value_counts().to_frame()
# Out:
#                                                 0
# percent_NAs experiment
# 100.00      dlib_rot90                        576
#             dlib_stateless_random_brightness  379
# 0.00        mediapipe_original                313
# 100.00      mediapipe_adjust_hue              285
#             dlib_adjust_jpeg_quality          275
# ...                                           ...
# 22.02       mediapipe_adjust_jpeg_quality       1
# 22.00       openface_rgb_to_grayscale           1
# 21.98       openface_adjust_jpeg_quality        1
#             mediapipe_rgb_to_grayscale          1
# 41.43       openface_rgb_to_grayscale           1
#
# [6567 rows x 1 columns]

# %%
df_diff_unit.groupby(['experiment'], as_index=False ).agg(['count'])
# Out:
#                                       index video_name extractor   aug    na  \
#                                       count      count     count count count
# experiment
# dlib_adjust_brightness                  592        592       592   592   592
# dlib_adjust_contrast                    592        592       592   592   592
# dlib_adjust_hue                         592        592       592   592   592
# dlib_adjust_jpeg_quality                592        592       592   592   592
# dlib_original                           592        592       592   592   592
# dlib_rgb_to_grayscale                   592        592       592   592   592
# dlib_rot90                              592        592       592   592   592
# dlib_stateless_random_brightness        592        592       592   592   592
# mediapipe_adjust_brightness             592        592       592   592   592
# mediapipe_adjust_contrast               592        592       592   592   592
# mediapipe_adjust_hue                    592        592       592   592   592
# mediapipe_adjust_jpeg_quality           592        592       592   592   592
# mediapipe_original                      592        592       592   592   592
# mediapipe_rgb_to_grayscale              592        592       592   592   592
# mediapipe_rot90                         592        592       592   592   592
# mediapipe_stateless_random_brightness   592        592       592   592   592
# openface_adjust_brightness              592        592       592   592   592
# openface_adjust_contrast                592        592       592   592   592
# openface_adjust_hue                     592        592       592   592   592
# openface_adjust_jpeg_quality            592        592       592   592   592
# openface_original                       592        592       592   592   592
# openface_rgb_to_grayscale               592        592       592   592   592
# openface_rot90                          592        592       592   592   592
# openface_stateless_random_brightness    592        592       592   592   592
#
#                                       counts_NAs total_frames percent_NAs
#                                            count        count       count
# experiment
# dlib_adjust_brightness                       592          592         592
# dlib_adjust_contrast                         592          592         592
# dlib_adjust_hue                              592          592         592
# dlib_adjust_jpeg_quality                     592          592         592
# dlib_original                                592          592         592
# dlib_rgb_to_grayscale                        592          592         592
# dlib_rot90                                   592          592         592
# dlib_stateless_random_brightness             592          592         592
# mediapipe_adjust_brightness                  592          592         592
# mediapipe_adjust_contrast                    592          592         592
# mediapipe_adjust_hue                         592          592         592
# mediapipe_adjust_jpeg_quality                592          592         592
# mediapipe_original                           592          592         592
# mediapipe_rgb_to_grayscale                   592          592         592
# mediapipe_rot90                              592          592         592
# mediapipe_stateless_random_brightness        592          592         592
# openface_adjust_brightness                   592          592         592
# openface_adjust_contrast                     592          592         592
# openface_adjust_hue                          592          592         592
# openface_adjust_jpeg_quality                 592          592         592
# openface_original                            592          592         592
# openface_rgb_to_grayscale                    592          592         592
# openface_rot90                               592          592         592
# openface_stateless_random_brightness         592          592         592

# %%
df_diff_unit.loc[df_diff_unit.experiment == 'dlib_rot90']
# Out:
#        index                video_name extractor    aug na  counts_NAs  \
# 6         13  v_ApplyEyeMakeup_g01_c01      dlib  rot90  1         164
# 30        61  v_ApplyEyeMakeup_g01_c02      dlib  rot90  1         123
# 54       109  v_ApplyEyeMakeup_g01_c03      dlib  rot90  1         259
# 78       157  v_ApplyEyeMakeup_g01_c04      dlib  rot90  1         235
# 102      205  v_ApplyEyeMakeup_g01_c05      dlib  rot90  1         296
# ...      ...                       ...       ...    ... ..         ...
# 14094  28189    v_ShavingBeard_g25_c02      dlib  rot90  1         226
# 14118  28237    v_ShavingBeard_g25_c03      dlib  rot90  1         230
# 14142  28285    v_ShavingBeard_g25_c04      dlib  rot90  1         161
# 14166  28333    v_ShavingBeard_g25_c05      dlib  rot90  1         242
# 14190  28381    v_ShavingBeard_g25_c06      dlib  rot90  1         235
#
#        total_frames  percent_NAs  experiment
# 6               164        100.0  dlib_rot90
# 30              123        100.0  dlib_rot90
# 54              259        100.0  dlib_rot90
# 78              235        100.0  dlib_rot90
# 102             296        100.0  dlib_rot90
# ...             ...          ...         ...
# 14094           226        100.0  dlib_rot90
# 14118           230        100.0  dlib_rot90
# 14142           161        100.0  dlib_rot90
# 14166           242        100.0  dlib_rot90
# 14190           235        100.0  dlib_rot90
#
# [592 rows x 9 columns]

# %%
dats_stats = pd.pivot(df_diff_unit[['experiment', 'percent_NAs']].reset_index(), values = 'percent_NAs', columns = 'experiment')
dats_stats
# Out:
# experiment  dlib_adjust_brightness  dlib_adjust_contrast  dlib_adjust_hue  \
# 0                            95.12                   NaN              NaN
# 1                              NaN                 74.39              NaN
# 2                              NaN                   NaN            61.59
# 3                              NaN                   NaN              NaN
# 4                              NaN                   NaN              NaN
# ...                            ...                   ...              ...
# 14203                          NaN                   NaN              NaN
# 14204                          NaN                   NaN              NaN
# 14205                          NaN                   NaN              NaN
# 14206                          NaN                   NaN              NaN
# 14207                          NaN                   NaN              NaN
#
# experiment  dlib_adjust_jpeg_quality  dlib_original  dlib_rgb_to_grayscale  \
# 0                                NaN            NaN                    NaN
# 1                                NaN            NaN                    NaN
# 2                                NaN            NaN                    NaN
# 3                              75.61            NaN                    NaN
# 4                                NaN          60.98                    NaN
# ...                              ...            ...                    ...
# 14203                            NaN            NaN                    NaN
# 14204                            NaN            NaN                    NaN
# 14205                            NaN            NaN                    NaN
# 14206                            NaN            NaN                    NaN
# 14207                            NaN            NaN                    NaN
#
# experiment  dlib_rot90  dlib_stateless_random_brightness  \
# 0                  NaN                               NaN
# 1                  NaN                               NaN
# 2                  NaN                               NaN
# 3                  NaN                               NaN
# 4                  NaN                               NaN
# ...                ...                               ...
# 14203              NaN                               NaN
# 14204              NaN                               NaN
# 14205              NaN                               NaN
# 14206              NaN                               NaN
# 14207              NaN                               NaN
#
# experiment  mediapipe_adjust_brightness  mediapipe_adjust_contrast  ...  \
# 0                                   NaN                        NaN  ...
# 1                                   NaN                        NaN  ...
# 2                                   NaN                        NaN  ...
# 3                                   NaN                        NaN  ...
# 4                                   NaN                        NaN  ...
# ...                                 ...                        ...  ...
# 14203                               NaN                        NaN  ...
# 14204                               NaN                        NaN  ...
# 14205                               NaN                        NaN  ...
# 14206                               NaN                        NaN  ...
# 14207                               NaN                        NaN  ...
#
# experiment  mediapipe_rot90  mediapipe_stateless_random_brightness  \
# 0                       NaN                                    NaN
# 1                       NaN                                    NaN
# 2                       NaN                                    NaN
# 3                       NaN                                    NaN
# 4                       NaN                                    NaN
# ...                     ...                                    ...
# 14203                   NaN                                    NaN
# 14204                   NaN                                    NaN
# 14205                   NaN                                    NaN
# 14206                   NaN                                    NaN
# 14207                   NaN                                    NaN
#
# experiment  openface_adjust_brightness  openface_adjust_contrast  \
# 0                                  NaN                       NaN
# 1                                  NaN                       NaN
# 2                                  NaN                       NaN
# 3                                  NaN                       NaN
# 4                                  NaN                       NaN
# ...                                ...                       ...
# 14203                              NaN                       NaN
# 14204                              NaN                       NaN
# 14205                              NaN                       NaN
# 14206                              NaN                       NaN
# 14207                              NaN                       NaN
#
# experiment  openface_adjust_hue  openface_adjust_jpeg_quality  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# ...                         ...                           ...
# 14203                       NaN                         99.57
# 14204                       NaN                           NaN
# 14205                       NaN                           NaN
# 14206                       NaN                           NaN
# 14207                       NaN                           NaN
#
# experiment  openface_original  openface_rgb_to_grayscale  openface_rot90  \
# 0                         NaN                        NaN             NaN
# 1                         NaN                        NaN             NaN
# 2                         NaN                        NaN             NaN
# 3                         NaN                        NaN             NaN
# 4                         NaN                        NaN             NaN
# ...                       ...                        ...             ...
# 14203                     NaN                        NaN             NaN
# 14204                   100.0                        NaN             NaN
# 14205                     NaN                      100.0             NaN
# 14206                     NaN                        NaN           95.32
# 14207                     NaN                        NaN             NaN
#
# experiment  openface_stateless_random_brightness
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 14203                                        NaN
# 14204                                        NaN
# 14205                                        NaN
# 14206                                        NaN
# 14207                                      100.0
#
# [14208 rows x 24 columns]

# %%
dats_stats = dats_stats.rename(columns={
    'dlib_dd':'D_brightness',
    'dlib_adjust_contrast':'D_contrast',
    'dlib_adjust_hue':'D_hue',
    'dlib_adjust_jpeg_quality':'D_quality',
    'dlib_original':'D_original',
    'dlib_rgb_to_grayscale':'D_grayscale',
    'dlib_d_random_brightness':'D_brightless',
    'dlib_rot90':'D_rot90',

    'mediapipe_dd':'M_brightness',
    'mediapipe_adjust_contrast':'M_contrast',
    'mediapipe_adjust_hue':'M_hue',
    'mediapipe_adjust_jpeg_quality':'M_quality',
    'mediapipe_original':'M_original',
    'mediapipe_rgb_to_grayscale':'M_grayscale',
    'mediapipe_rot90':'M_rot90',
    'mediapipe_d_random_brightness':'M_brightless',

    'openface_dd':'O_brightness',
    'openface_adjust_contrast':'O_contrast',
    'openface_adjust_hue':'O_hue',
    'openface_adjust_jpeg_quality':'O_quality',
    'openface_original':'O_original',
    'openface_rgb_to_grayscale':'O_grayscale',
    'openface_rot90':'O_rot90',
    'openface_d_random_brightness':'O_brightless'}

)
dats_stats
# Out:
# experiment  dlib_adjust_brightness  D_contrast  D_hue  D_quality  D_original  \
# 0                            95.12         NaN    NaN        NaN         NaN
# 1                              NaN       74.39    NaN        NaN         NaN
# 2                              NaN         NaN  61.59        NaN         NaN
# 3                              NaN         NaN    NaN      75.61         NaN
# 4                              NaN         NaN    NaN        NaN       60.98
# ...                            ...         ...    ...        ...         ...
# 14203                          NaN         NaN    NaN        NaN         NaN
# 14204                          NaN         NaN    NaN        NaN         NaN
# 14205                          NaN         NaN    NaN        NaN         NaN
# 14206                          NaN         NaN    NaN        NaN         NaN
# 14207                          NaN         NaN    NaN        NaN         NaN
#
# experiment  D_grayscale  D_rot90  dlib_stateless_random_brightness  \
# 0                   NaN      NaN                               NaN
# 1                   NaN      NaN                               NaN
# 2                   NaN      NaN                               NaN
# 3                   NaN      NaN                               NaN
# 4                   NaN      NaN                               NaN
# ...                 ...      ...                               ...
# 14203               NaN      NaN                               NaN
# 14204               NaN      NaN                               NaN
# 14205               NaN      NaN                               NaN
# 14206               NaN      NaN                               NaN
# 14207               NaN      NaN                               NaN
#
# experiment  mediapipe_adjust_brightness  M_contrast  ...  M_rot90  \
# 0                                   NaN         NaN  ...      NaN
# 1                                   NaN         NaN  ...      NaN
# 2                                   NaN         NaN  ...      NaN
# 3                                   NaN         NaN  ...      NaN
# 4                                   NaN         NaN  ...      NaN
# ...                                 ...         ...  ...      ...
# 14203                               NaN         NaN  ...      NaN
# 14204                               NaN         NaN  ...      NaN
# 14205                               NaN         NaN  ...      NaN
# 14206                               NaN         NaN  ...      NaN
# 14207                               NaN         NaN  ...      NaN
#
# experiment  mediapipe_stateless_random_brightness  openface_adjust_brightness  \
# 0                                             NaN                         NaN
# 1                                             NaN                         NaN
# 2                                             NaN                         NaN
# 3                                             NaN                         NaN
# 4                                             NaN                         NaN
# ...                                           ...                         ...
# 14203                                         NaN                         NaN
# 14204                                         NaN                         NaN
# 14205                                         NaN                         NaN
# 14206                                         NaN                         NaN
# 14207                                         NaN                         NaN
#
# experiment  O_contrast  O_hue  O_quality  O_original  O_grayscale  O_rot90  \
# 0                  NaN    NaN        NaN         NaN          NaN      NaN
# 1                  NaN    NaN        NaN         NaN          NaN      NaN
# 2                  NaN    NaN        NaN         NaN          NaN      NaN
# 3                  NaN    NaN        NaN         NaN          NaN      NaN
# 4                  NaN    NaN        NaN         NaN          NaN      NaN
# ...                ...    ...        ...         ...          ...      ...
# 14203              NaN    NaN      99.57         NaN          NaN      NaN
# 14204              NaN    NaN        NaN       100.0          NaN      NaN
# 14205              NaN    NaN        NaN         NaN        100.0      NaN
# 14206              NaN    NaN        NaN         NaN          NaN    95.32
# 14207              NaN    NaN        NaN         NaN          NaN      NaN
#
# experiment  openface_stateless_random_brightness
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 14203                                        NaN
# 14204                                        NaN
# 14205                                        NaN
# 14206                                        NaN
# 14207                                      100.0
#
# [14208 rows x 24 columns]

# %%
FIM
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-aad5ff3c8db5> in <module>
# ----> 1 FIM
#
# NameError: name 'FIM' is not defined

# %%
#df_diff_unit.to_csv("../../data/outputs/UCF-101-Analysis/comparison-extractors_estimation_stats.csv", sep=',', index=False)

# %% [markdown]
# # Análise visual

# %%
path_visual = './../../data/raw/UCF-101-Analysis/ApplyEyeMakeup/'
l_videos = sorted(os.listdir(path_visual))

video1 = media.read_video(path_visual+str(l_videos[0]))
video2 = media.read_video(path_visual+str(l_videos[1]))
video3 = media.read_video(path_visual+str(l_videos[2]))
video4 = media.read_video(path_visual+str(l_videos[3]))
video5 = media.read_video(path_visual+str(l_videos[4]))
video6 = media.read_video(path_visual+str(l_videos[5]))
video7 = media.read_video(path_visual+str(l_videos[6]))
video8 = media.read_video(path_visual+str(l_videos[7]))
video9 = media.read_video(path_visual+str(l_videos[8]))
video10 = media.read_video(path_visual+str(l_videos[9]))

# Show multiple videos side-by-side.
s = 90
vis_videos = {
    'v_ApplyEyeMakeup_g01_c02-DLIB': video1,
    'v_ApplyEyeMakeup_g01_c02-MEDIAPIPE': video2,
    'v_PlayingFlute_g02_c06-DLIB': video3,
    'v_PlayingFlute_g02_c06-MEDIAPIPE': video4,
    'v_PlayingFlute_g03_c07-DLIB': video5,
    'v_PlayingFlute_g03_c07-MEDIAPIPE': video6,
    'v_ShavingBeard_g03_c03-DLIB': video7,
    'v_ShavingBeard_g03_c03-MEDIAPIPE': video8,
    'v_ShavingBeard_g04_c02-DLIB': video9,
    'v_ShavingBeard_g04_c02-MEDIAPIPE': video10,
    
}
media.show_videos(vis_videos, fps=25, columns=2)

# %% [markdown]
# # Por classe

# %%
fig = plt.figure(figsize=(14,8))

ax =  sns.displot(
    df_diff_unit, x="percent_notna", row="extractor", col="aug", hue='class',
     height=3, facet_kws=dict(margin_titles=True), kind="kde", 
)
ax.set(ylabel='Total of Frames with Landmarks')

# %% [markdown]
# De maneira geral, analisando as figuras acima, podemos perceber que na maior parte dos casos, ambos os extratores, tiveram uma taxa maior de detecção em frames da classe ApplyEyeMakeup, enquanto que para as classes PlayingFlute e ShavingBeard, ambos os extratores apresentaram as menores taxas de detecção.

# %%
def get_total_frames_class(ext, aug, total_frames):
    return total_frames.loc[(total_frames.extractor == ext) & 
                            (total_frames.aug == aug)].reset_index().at[0,'total_frames'] #index, col

# %%
total_frames = df_combined.groupby(['extractor', 'aug', 'class']).size().reset_index(name='total_frames')

df_diff_class = df_combined.groupby(['extractor', 'aug', 'class', 'na']).size().reset_index(name='counts_notna')
df_diff_class = df_diff_class.loc[df_diff_class.na == 0].reset_index()
df_diff_class['total_frames'] = df_diff_class.apply(lambda x: get_total_frames_class( x['extractor'], x['aug'], total_frames), axis=1)
df_diff_class['percent_notna'] = df_diff_class['counts_notna']/df_diff_class['total_frames']*100
df_diff_class#.loc[df_diff_unit['class'] == 'v_ApplyEyeMakeup_g01_c01.avi']

# %%
fig = plt.figure(figsize=(14,8))

ax =  sns.displot(
    df_diff_class, x="percent_notna", col="extractor", row="aug",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)
ax.set(ylabel='Total of Frames with Landmarks')

# %% [markdown]
# # Outilers

# %%
ff

# %%
g = sns.FacetGrid(ff, col='aug',col_wrap=2)
#                                               change this to 4 ^
g.map(sns.boxplot,'extractor','percent_notna',palette='muted', order=['mediapipe', 'dlib', 'openface'])
for ax in g.axes.flatten(): 
    ax.tick_params(labelbottom=True)
plt.tight_layout()
plt.show()

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'mediapipe') &
                (df_diff_unit.extractor == 'openface')].percent_notna.describe()

# %% [markdown]
# ### Outliers MediaPipe

# %%
df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'dlib')]

# %%
#https://stackoverflow.com/questions/23199796/detect-and-exclude-outliers-in-pandas-data-frame
df = df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'mediapipe')]
df[(np.abs(stats.zscore(df['percent_notna'])) > 3)].sort_values(by = 'percent_notna')

# %%
df[(np.abs(stats.zscore(df['percent_notna'])) > 3)].sort_values(by = 'percent_notna').sample(n=5, random_state=1)

# %% [markdown]
# ### Outliers Dlib

# %%
df = df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'dlib')]
df[(np.abs(stats.zscore(df['percent_notna'])) > 3)].sort_values(by = 'percent_notna')

# %% [markdown]
# ### Outliers OpenFace

# %%
df = df_diff_unit.loc[(df_diff_unit.aug == 'original') & 
                 (df_diff_unit.extractor == 'openface')]
df[(np.abs(stats.zscore(df['percent_notna'])) > 3)].sort_values(by = 'percent_notna')

# %%
df['path'] = df[['class', 'video_name']].agg('/'.join, axis=1)
l_videos = df.sample(n=10, random_state=1).reset_index()['path']
df.sample(n=10, random_state=1).reset_index()[['video_name', 'percent_notna']].sort_values(by='percent_notna')

# %%
l_videos

# %%
path_visual = './../../data/raw/UCF-101-Analysis/'
#l_videos = sorted(os.listdir(path_visual+classe))

video1 = media.read_video(path_visual+str(l_videos[0]))
video2 = media.read_video(path_visual+str(l_videos[1]))
video3 = media.read_video(path_visual+str(l_videos[2]))
video4 = media.read_video(path_visual+str(l_videos[3]))
video5 = media.read_video(path_visual+str(l_videos[4]))
video6 = media.read_video(path_visual+str(l_videos[5]))
video7 = media.read_video(path_visual+str(l_videos[6]))
video8 = media.read_video(path_visual+str(l_videos[7]))
video9 = media.read_video(path_visual+str(l_videos[8]))
video10 = media.read_video(path_visual+str(l_videos[9]))

# Show multiple videos side-by-side.
s = 90
vis_videos = {
    l_videos[0]: video1,
    l_videos[1]: video2,
    l_videos[2]: video3,
    l_videos[3]: video4,
    l_videos[4]: video5,
    l_videos[5]: video6,
    l_videos[6]: video7,
    l_videos[7]: video8,
    l_videos[8]: video9,
    l_videos[9]: video10,
    
}
media.show_videos(vis_videos, fps=25, columns=2)

# %%
- Escala de Cinza
- Super Resolution
- Motion Blur

# %%
Histograma, por categoria/similaridade.

Teste de Hipótese com os valores de diferença de cada amostra para o geral
